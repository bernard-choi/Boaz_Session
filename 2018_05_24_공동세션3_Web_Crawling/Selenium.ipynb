# %%
#pip install selenium
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome('C:\driver\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://www.nytimes.com/section/us?action=click&pgtype=Homepage&region=TopBar&module=HPMiniNav&contentCollection=U.S.&WT.nav=page')

# %%
show_btn = driver.find_element_by_class_name("buttons")
show_btn.click()

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser') 

title=[]

# %%
for page in range(20) :
    titles = soup.find_all('h2',{'class':'headline'})
    for i in titles:
        title.append(i.text.strip())
    #show_btn = driver.find_element_by_class_name("buttons")
    #show_btn.click()

# %%
print(title)
# Out:
# ['There Are Two Georgias. One Just Made History.', 'Georgia Jury Returns $1 Billion Verdict in Sexual Assault Case', 'Sterling Brown Arrest Video Shows Milwaukee Police Using Stun Gun on N.B.A. Player', 'Scratch and Sniff Stamps Are Coming to Your Mailbox', '‘This Is Not of God’: When Anti-Trump Evangelicals Confront Their Brethren', 'Transgender Student in Bathroom Dispute Wins Court Ruling', 'Georgia Primary Election Results', '200 Professors Call for Ouster of U.S.C. President, Citing Lack of ‘Moral Authority’', 'Grand Jury Declines to Indict Officers in Georgia Man’s Killing', 'Overlooked No More: She Followed a Trail to Wyoming. Then She Blazed One.', 'Southern Baptist Leader Removed as Seminary President for Remarks on Women', '‘They Can’t Ignore Us Anymore’: Women Firefighters Allege Culture of Discrimination', 'Trump, Visiting Epicenter of MS-13 Killings, Demands Tougher Immigration Laws', 'Senate Sends Major Overhaul of Veterans Health Care to Trump', 'Trump, Georgia, N.F.L.
# ...

# %%
summary= []
for i in soup.find_all('p',{'class':'summary'}):
    print(i.text)
    summary.append(i.text)
# Out:
# The victory of Stacey Abrams, the first black woman to win a major party’s nomination for governor, highlights the divide between Georgia’s diverse cities, led by Atlanta, and its conservative countryside.
# Hope Cheston was 14 when she was raped by a security guard. Several lawyers said it was the largest verdict ever given to a sexual assault survivor.
# Police conduct toward black people has been a fraught issue in Milwaukee. The city’s mayor said: ‘As a human being, I am offended by what I saw.’
# In June, the Postal Service will unveil stamps using the 50-year-old technique associated with perfume ads and the John Waters film “Polyester.”
# Concerned evangelicals staged a revival in Liberty University’s backyard to challenge Jerry Falwell Jr. and his alliance with President Trump.
# Gavin Grimm was barred from using the boys’ restrooms at his Virginia high school. He sued in a case that went all the way to the Supreme Court.
# ...

# %%
driver.quit()
